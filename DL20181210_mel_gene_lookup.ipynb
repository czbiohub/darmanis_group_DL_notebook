# %% [markdown]
# # [shift + return] to execute setup chunk
# - Takes about 5 min
# - Only needs to be executed after reboot

# %%
# %reload_ext autoreload
# %autoreload 2

from lookup_setup import *

full_adata, adata_subset1, adata_subset2, adata_subset3 = main()
adatas = [full_adata, adata_subset1, adata_subset2, adata_subset3]

# %% [markdown]
# # [shift + return] to execute single-gene plotting chunk
# - UMAP + violin plots grouped by louvain clustering

# %%
gene = "TLR2"
single_gene(gene,adatas)
# Out:
# all-cells
# ... storing 'outliers' as categorical
# adt-mel
# ... storing 'outliers' as categorical
# adt-mel sans outlier cells
# adt_mel sans all outliers

# %% [markdown]
# # [shift + return] to execute multi-gene plotting chunk
# - UMAP + boxplots + histograms grouped by louvain clustering

# %%
gene_list = ["LRRTM1","LRRTM2","LRRTM3","LRRTM4","NLGN1","NLGN2","NLGN3","NRXN1","NRXN2","NRXN3","L1CAM","CADM1","CADM2","CADM3","CADM4","NECTIN3","NECTIN1","AFDN"]
multi_gene (gene_list, adatas)
# Out:
# all-cells
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d82b7d79c596> in <module>()
#       1 gene_list = ["LRRTM1","LRRTM2","LRRTM3","LRRTM4","NLGN1","NLGN2","NLGN3","NRXN1","NRXN2","NRXN3","L1CAM","CADM1","CADM2","CADM3","CADM4","NECTIN3","NECTIN1","AFDN"]
# ----> 2 multi_gene (gene_list, adatas)
#
# ~/git/biohub_scratch1/lookup_setup.py in multi_gene(gene_list, adatas)
#     849     for adata in adatas:
#     850         print(desc_key[str(adata)])
# --> 851         sc.pl.umap(adata, color=gene_list + ["louvain"])
#     852
#     853         input_adata = adata
#
# ~/anaconda3/lib/python3.6/site-packages/scanpy/plotting/tools/scatterplots.py in umap(adata, **kwargs)
#      27     If `show==False` a `matplotlib.Axis` or a list of it.
#      28     """
# ---> 29     return plot_scatter(adata, basis='umap', **kwargs)
#      30
#      31
#
# ~/anaconda3/lib/python3.6/site-packages/scanpy/plotting/tools/scatterplots.py in plot_scatter(adata, color, use_raw, sort_order, edges, edges_width, edges_color, arrows, arrows_kwds, basis, groups, components, projection, color_map, palette, size, frameon, legend_fontsize, legend_fontweight, legend_loc, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     273         color_vector, categorical = _get_color_values(adata, value_to_plot,
#     274                                                       groups=groups, palette=palette,
# --> 275                                                       use_raw=use_raw)
#     276
#     277         # check if higher value points should be plot on top
#
# ~/anaconda3/lib/python3.6/site-packages/scanpy/plotting/tools/scatterplots.py in _get_color_values(adata, value_to_plot, groups, palette, use_raw)
#     664         raise ValueError("The passed `color` {} is not a valid observation annotation "
#     665                          "or variable name. Valid observation annotation keys are: {}"
# --> 666                          .format(value_to_plot, adata.obs.columns))
#     667
#     668     return color_vector, categorical
#
# ValueError: The passed `color` NECTIN3 is not a valid observation annotation or variable name. Valid observation annotation keys are: Index(['total_features_by_counts', 'log1p_total_features_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_features',
#        'pct_counts_in_top_100_features', 'pct_counts_in_top_200_features',
#        'pct_counts_in_top_500_features', 'total_counts_ribo',
#        'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_ercc',
#        'log1p_total_counts_ercc', 'pct_counts_ercc', 'age', 'age_bin', 'plate',
#        'general_location', 'anatomical_location', 'race', 'sex', 'color',
#        'patient', 'bsc', 'PMEL', 'KRT1', 'KRT5', 'KRT10', 'TYR', 'MITF',
#        'n_genes', 'n_counts', 'louvain', 'outliers'],
#       dtype='object')
